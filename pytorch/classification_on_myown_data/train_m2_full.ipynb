# %%
import time
import glob
import torch
import torch.nn as nn
import torch.optim as optim
import os

print('PyTorch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# PyTorch 1.4.0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', major=6, minor=0, total_memory=16280MB, multi_processor_count=56)

# %%
from google.colab import drive
drive.mount('/content/drive/')  # 将google硬盘挂载在/comtent/drive/目录上面
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
path  = '/content/drive/My Drive/Colab Notebooks/glasses_classification'
os.chdir(path)
import sys
sys.path.insert(0, '.')
from mobilenetv2_full import mobilenetv2
from logger import Logger,savefig

#!unzip glasses_training_data.zip

# %%
#####build the network model
model = mobilenetv2(num_classes=2, width_mult=0.1)
print('    Total params: %.2fM' % (sum(p.numel() for p in model.parameters())/1000000.0))
#打印模型架构
#print(model)
# Out:
#     Total params: 0.08M

# %%
#a = torch.rand([1,3,64,64])
#outputs = model(a)
#print(outputs)
# Out:
# tensor([[-0.6890, -0.1649]], grad_fn=<AddmmBackward>)

# %%
###load the pretrained weights，下载的预训练模型
pretrained_path = 'weights/mobilenetv2_0.1-7d1d638a.pth'

print("Initializing the network ...")
#读入预训练模型的参数
#pytorch存储的模型一般采取存储网络参数格式，保存的格式为字典的格式，键为定义每层op的名字，值为保存的参数值

state_dict = torch.load(pretrained_path)

###去掉全链接层的权重，
#由于我们一般不会直接使用，imagenet的1000类，因此，我们需要更换网络最后的全链接层
#因此我们需要将前边几层的参数保存，最后一层重新初始化
#定义一个新的字典，将原始的参数字典，对应保存与更改
from collections import OrderedDict
new_state_dict = OrderedDict()

for k,v in state_dict.items():
    #print(k)  #打印预训练模型的键，如果发现与网络定义的键有一定的差别，可以更改对应的键值，
    #torchvision中的网络定义，采用了正则表达式，来更改键值，因为这里简单，没有再去构建正则表达式
    ##最后一层的全连接层，进行初始化
    if k.split('.')[0] == 'classifier':
        if k.split('.')[-1] == 'weights':
            v = nn.init.kaiming_normal(model.state_dict()[k], mode='fan_out')
        else:
            model.state_dict()[k][...] = 0.0
            v = model.state_dict()[k][...]
    ##得到新的与定义网络对应的预训练参数
    new_state_dict[k] = v
    #print('init,key',k)
##导入网络参数
model.load_state_dict(new_state_dict)
print("initialize the network done")
# Out:
# Initializing the network ...
# initialize the network done

# %%
from torchvision import transforms, datasets
# 构建数据提取器，利用dataloader
# 利用torchvision中的transforms进行图像预处理

input_size = 64
batch_size = 64
'''
    brightness (float): How much to jitter brightness. brightness_factor
            is chosen uniformly from [max(0, 1 - brightness), 1 + brightness].
        contrast (float): How much to jitter contrast. contrast_factor
            is chosen uniformly from [max(0, 1 - contrast), 1 + contrast].
        saturation (float): How much to jitter saturation. saturation_factor
            is chosen uniformly from [max(0, 1 - saturation), 1 + saturation].
        hue(float): How much to jitter hue. hue_factor is chosen uniformly from
            [-hue, hue]. Should be >=0 and <= 0.5.
    '''
train_transforms = transforms.Compose([
    transforms.RandomRotation(10),#随机10度以内旋转
    transforms.Resize((64,64)),
    transforms.RandomHorizontalFlip(),#随机水平翻转
    transforms.ColorJitter(brightness=1,contrast=1,hue=0.4),
    transforms.ToTensor(),
    transforms.Normalize((.5, .5, .5), (.5, .5, .5))
])

val_transforms = transforms.Compose([
    transforms.Resize((64,64)),
    transforms.ToTensor(),
    transforms.Normalize((.5, .5, .5), (.5, .5, .5))
])

##ImageFolder对象可以将一个文件夹下的文件构造成一类
#所以数据集的存储格式为一个类的图片放置到一个文件夹下
#然后利用dataloader构建提取器，每次返回一个batch的数据，在很多情况下，利用num_worker参数
#设置多线程，来相对提升数据提取的速度

train_dir = 'glasses_training_data/train'
train_datasets = datasets.ImageFolder(train_dir, transform=train_transforms)
train_dataloader = torch.utils.data.DataLoader(train_datasets, batch_size=batch_size, shuffle=True, num_workers=2)


val_dir = 'glasses_training_data/val'
val_datasets = datasets.ImageFolder(val_dir, transform=val_transforms)
val_dataloader = torch.utils.data.DataLoader(val_datasets, batch_size=batch_size, shuffle=True, num_workers=2)

# %%
from torch.optim import lr_scheduler

learning_rate=0.005
max_epoch=300
val_epoch=10#每10个epoch，验证一下
save_folder='weights/'
log_folder='logs'
log_file='train_0220_2.log'


log_variable_name = ['Learning_Rate','Train_Loss','Valid_Loss','Train_Acc','Valid_Acc']
log_variable_dict = {k:0.0 for k in log_variable_name}
###日志模块
if not os.path.exists(log_folder):
    os.system('mkdir -p {}'.format(log_folder))
logger = Logger(os.path.join(log_folder, log_file), title='0220 1')
logger.set_names(['Learning Rate', 'Train Loss', 'Valid Loss', 'Train Acc.', 'Valid Acc.'])

###模型放置在gpu上进行计算
if torch.cuda.is_available():
    model.cuda()

##定义优化器与损失函数
optimizer = optim.SGD(model.parameters(), lr=learning_rate, momentum=0.9,weight_decay=5e-4)
scheduler = lr_scheduler.StepLR(optimizer, step_size=50, gamma=0.5)
loss_func = nn.CrossEntropyLoss()

#每一个epoch含有多少个batch
max_batch = len(train_datasets)//batch_size
best_acc = 0#用来保存精度最高的模型
##训练max——epoch个epoch
for epoch in range(max_epoch):
    model.train()  ##在进行训练时加上train()，测试时加上eval()
    batch = 0
    train_acc = 0.0
    train_loss = 0.0
    for batch_images, batch_labels in train_dataloader:
        ##在pytorch0.4之后将Variable 与tensor进行合并，所以这里不需要进行Variable封装
        if torch.cuda.is_available():
            batch_images, batch_labels = batch_images.cuda(),batch_labels.cuda()
        
        optimizer.zero_grad() #清空梯度信息，否则在每次进行反向传播时都会累加
        out = model(batch_images)
        #print('out',out)
        loss = loss_func(out,batch_labels)
        #print('batch_labels',batch_labels)
        #print('loss',loss)
        train_loss += loss
        prediction = torch.max(out,1)[1]
        #print('prediction',prediction)

        train_correct = (prediction == batch_labels).sum()
        ##这里得到的train_correct是一个longtensor型，需要转换为float
        # print(train_correct.type())
        train_acc += train_correct
 #       print(train_acc.type())
        loss.backward()  #loss反向传播
        optimizer.step()  ##梯度更新
        
        batch+=1
        #print("Epoch: %d/%d || batch:%d/%d average_loss: %.3f || train_acc: %.2f"
        #      %(epoch, max_epoch, batch, max_batch, average_loss, train_acc))
    log_variable_dict['Learning_Rate'] = scheduler.get_lr()[0]
    log_variable_dict['Train_Loss'] = train_loss.data.item()/batch
    log_variable_dict['Train_Acc'] = train_acc.data.item()/ len(train_datasets)
    print("Epoch: %d/%d || lr:%.6f || train_loss: %.3f || train_acc: %.3f"
            %(epoch,max_epoch,log_variable_dict['Learning_Rate'], log_variable_dict['Train_Loss'],log_variable_dict['Train_Acc']))
    scheduler.step()
    
    if (epoch+1)%val_epoch==0:#val
        ##进行模型测试时，eval（）会固定下BN与Dropout的参数
        model.eval()
        eval_acc = 0.0
        val_loss = 0.0
        batch = 0
        for batch_images, batch_labels in val_dataloader:
            # print(batch_labels)
            with torch.no_grad():
                if torch.cuda.is_available():
                    batch_images, batch_labels = batch_images.cuda(), batch_labels.cuda()

            out = model(batch_images)
            loss = loss_func(out,batch_labels)
            val_loss += loss

            prediction = torch.max(out, 1)[1]
            num_correct = (prediction == batch_labels).sum()
            eval_acc += num_correct
            #print(eval_acc)
            batch += 1
        
        log_variable_dict['Valid_Loss'] = val_loss.data.item()/batch
        eval_acc = eval_acc.data.item() / len(val_datasets)
        log_variable_dict['Valid_Acc'] = eval_acc

        # append logger file
        logger.append([log_variable_dict[k] for k in log_variable_name])
        print("val_loss: %.3f || val_acc: %.3f"%(log_variable_dict['Valid_Loss'],log_variable_dict['Valid_Acc']))
        if eval_acc > best_acc:
            best_acc = eval_acc
            torch.save(model.state_dict(), os.path.join(save_folder,'best.pth'))
    ##每10epoch保存一次模型
    if (epoch+1)%10 ==0:
        torch.save(model.state_dict(), os.path.join(save_folder,'last.pth'))
logger.close()
logger.plot()
savefig(os.path.join('logs', log_file.replace('.log','.eps')))
# Out:
# Epoch: 0/300 || lr:0.005000 || train_loss: 0.659 || train_acc: 0.660
# Epoch: 1/300 || lr:0.005000 || train_loss: 0.736 || train_acc: 0.696
# Epoch: 2/300 || lr:0.005000 || train_loss: 0.697 || train_acc: 0.701
# Epoch: 3/300 || lr:0.005000 || train_loss: 0.636 || train_acc: 0.751
# Epoch: 4/300 || lr:0.005000 || train_loss: 0.786 || train_acc: 0.729
# Epoch: 5/300 || lr:0.005000 || train_loss: 0.581 || train_acc: 0.774
# Epoch: 6/300 || lr:0.005000 || train_loss: 0.615 || train_acc: 0.767
# Epoch: 7/300 || lr:0.005000 || train_loss: 0.606 || train_acc: 0.747
# Epoch: 8/300 || lr:0.005000 || train_loss: 0.582 || train_acc: 0.786
# Epoch: 9/300 || lr:0.005000 || train_loss: 0.749 || train_acc: 0.738
# val_loss: 1.687 || val_acc: 0.744
# Epoch: 10/300 || lr:0.005000 || train_loss: 0.730 || train_acc: 0.778
# Epoch: 11/300 || lr:0.005000 || train_loss: 0.619 || train_acc: 0.772
# Epoch: 12/300 || lr:0.005000 || train_loss: 0.488 || train_acc: 0.822
# Epoch: 13/300 || lr:0.005000 || train_loss: 0.475 || train_acc: 0.802
# Epoch: 14/300 || lr:0.005000 || train_loss: 0.579 || train_acc: 0.777
# Epoch: 15/300 || lr:0.005000 || train_loss: 0.560 || train_acc: 0.789
# Epoch: 16/300 || lr:0.005000 || train_loss: 0.479 || train_acc: 0.808
# Epoch: 17/300 || lr:0.005000 || train_loss: 0.444 || train_acc: 0.813
# Epoch: 18/300 || lr:0.005000 || train_loss: 0.408 || train_acc: 0.821
# Epoch: 19/300 || lr:0.005000 || train_loss: 0.484 || train_acc: 0.821
# val_loss: 0.433 || val_acc: 0.850
# Epoch: 20/300 || lr:0.005000 || train_loss: 0.397 || train_acc: 0.827
# Epoch: 21/300 || lr:0.005000 || train_loss: 0.471 || train_acc: 0.822
# Epoch: 22/300 || lr:0.005000 || train_loss: 0.379 || train_acc: 0.834
# Epoch: 23/300 || lr:0.005000 || train_loss: 0.487 || train_acc: 0.804
# Epoch: 24/300 || lr:0.005000 || train_loss: 0.386 || train_acc: 0.821
# Epoch: 25/300 || lr:0.005000 || train_loss: 0.367 || train_acc: 0.854
# Epoch: 26/300 || lr:0.005000 || train_loss: 0.390 || train_acc: 0.839
# Epoch: 27/300 || lr:0.005000 || train_loss: 0.359 || train_acc: 0.844
# Epoch: 28/300 || lr:0.005000 || train_loss: 0.358 || train_acc: 0.845
# Epoch: 29/300 || lr:0.005000 || train_loss: 0.365 || train_acc: 0.840
# val_loss: 0.404 || val_acc: 0.838
# Epoch: 30/300 || lr:0.005000 || train_loss: 0.388 || train_acc: 0.840
# Epoch: 31/300 || lr:0.005000 || train_loss: 0.374 || train_acc: 0.845
# Epoch: 32/300 || lr:0.005000 || train_loss: 0.374 || train_acc: 0.853
# Epoch: 33/300 || lr:0.005000 || train_loss: 0.492 || train_acc: 0.820
# Epoch: 34/300 || lr:0.005000 || train_loss: 0.440 || train_acc: 0.808
# Epoch: 35/300 || lr:0.005000 || train_loss: 0.417 || train_acc: 0.832
# Epoch: 36/300 || lr:0.005000 || train_loss: 0.341 || train_acc: 0.865
# Epoch: 37/300 || lr:0.005000 || train_loss: 0.368 || train_acc: 0.828
# Epoch: 38/300 || lr:0.005000 || train_loss: 0.318 || train_acc: 0.871
# Epoch: 39/300 || lr:0.005000 || train_loss: 0.318 || train_acc: 0.853
# val_loss: 0.312 || val_acc: 0.863
# Epoch: 40/300 || lr:0.005000 || train_loss: 0.338 || train_acc: 0.843
# Epoch: 41/300 || lr:0.005000 || train_loss: 0.357 || train_acc: 0.848
# Epoch: 42/300 || lr:0.005000 || train_loss: 0.352 || train_acc: 0.849
# Epoch: 43/300 || lr:0.005000 || train_loss: 0.352 || train_acc: 0.844
# Epoch: 44/300 || lr:0.005000 || train_loss: 0.423 || train_acc: 0.827
# Epoch: 45/300 || lr:0.005000 || train_loss: 0.373 || train_acc: 0.839
# Epoch: 46/300 || lr:0.005000 || train_loss: 0.376 || train_acc: 0.845
# Epoch: 47/300 || lr:0.005000 || train_loss: 0.347 || train_acc: 0.862
# Epoch: 48/300 || lr:0.005000 || train_loss: 0.286 || train_acc: 0.875
# Epoch: 49/300 || lr:0.005000 || train_loss: 0.331 || train_acc: 0.868
# val_loss: 0.337 || val_acc: 0.872
# Epoch: 50/300 || lr:0.001250 || train_loss: 0.328 || train_acc: 0.851
# Epoch: 51/300 || lr:0.002500 || train_loss: 0.282 || train_acc: 0.873
# Epoch: 52/300 || lr:0.002500 || train_loss: 0.274 || train_acc: 0.886
# Epoch: 53/300 || lr:0.002500 || train_loss: 0.259 || train_acc: 0.895
# Epoch: 54/300 || lr:0.002500 || train_loss: 0.276 || train_acc: 0.875
# Epoch: 55/300 || lr:0.002500 || train_loss: 0.310 || train_acc: 0.863
# Epoch: 56/300 || lr:0.002500 || train_loss: 0.240 || train_acc: 0.893
# Epoch: 57/300 || lr:0.002500 || train_loss: 0.243 || train_acc: 0.896
# Epoch: 58/300 || lr:0.002500 || train_loss: 0.281 || train_acc: 0.870
# Epoch: 59/300 || lr:0.002500 || train_loss: 0.276 || train_acc: 0.877
# val_loss: 0.256 || val_acc: 0.902
# Epoch: 60/300 || lr:0.002500 || train_loss: 0.236 || train_acc: 0.900
# Epoch: 61/300 || lr:0.002500 || train_loss: 0.255 || train_acc: 0.891
# Epoch: 62/300 || lr:0.002500 || train_loss: 0.254 || train_acc: 0.892
# Epoch: 63/300 || lr:0.002500 || train_loss: 0.289 || train_acc: 0.871
# Epoch: 64/300 || lr:0.002500 || train_loss: 0.269 || train_acc: 0.879
# Epoch: 65/300 || lr:0.002500 || train_loss: 0.264 || train_acc: 0.887
# Epoch: 66/300 || lr:0.002500 || train_loss: 0.246 || train_acc: 0.885
# Epoch: 67/300 || lr:0.002500 || train_loss: 0.250 || train_acc: 0.889
# Epoch: 68/300 || lr:0.002500 || train_loss: 0.255 || train_acc: 0.897
# Epoch: 69/300 || lr:0.002500 || train_loss: 0.264 || train_acc: 0.883
# val_loss: 0.289 || val_acc: 0.876
# Epoch: 70/300 || lr:0.002500 || train_loss: 0.256 || train_acc: 0.900
# Epoch: 71/300 || lr:0.002500 || train_loss: 0.239 || train_acc: 0.893
# Epoch: 72/300 || lr:0.002500 || train_loss: 0.249 || train_acc: 0.884
# Epoch: 73/300 || lr:0.002500 || train_loss: 0.284 || train_acc: 0.879
# Epoch: 74/300 || lr:0.002500 || train_loss: 0.249 || train_acc: 0.886
# Epoch: 75/300 || lr:0.002500 || train_loss: 0.254 || train_acc: 0.884
# Epoch: 76/300 || lr:0.002500 || train_loss: 0.250 || train_acc: 0.884
# Epoch: 77/300 || lr:0.002500 || train_loss: 0.225 || train_acc: 0.901
# Epoch: 78/300 || lr:0.002500 || train_loss: 0.254 || train_acc: 0.877
# Epoch: 79/300 || lr:0.002500 || train_loss: 0.224 || train_acc: 0.905
# val_loss: 0.279 || val_acc: 0.902
# Epoch: 80/300 || lr:0.002500 || train_loss: 0.242 || train_acc: 0.896
# Epoch: 81/300 || lr:0.002500 || train_loss: 0.283 || train_acc: 0.887
# Epoch: 82/300 || lr:0.002500 || train_loss: 0.271 || train_acc: 0.883
# Epoch: 83/300 || lr:0.002500 || train_loss: 0.258 || train_acc: 0.882
# Epoch: 84/300 || lr:0.002500 || train_loss: 0.265 || train_acc: 0.889
# Epoch: 85/300 || lr:0.002500 || train_loss: 0.227 || train_acc: 0.913
# Epoch: 86/300 || lr:0.002500 || train_loss: 0.248 || train_acc: 0.878
# Epoch: 87/300 || lr:0.002500 || train_loss: 0.249 || train_acc: 0.895
# Epoch: 88/300 || lr:0.002500 || train_loss: 0.246 || train_acc: 0.889
# Epoch: 89/300 || lr:0.002500 || train_loss: 0.270 || train_acc: 0.885
# val_loss: 0.248 || val_acc: 0.910
# Epoch: 90/300 || lr:0.002500 || train_loss: 0.254 || train_acc: 0.881
# Epoch: 91/300 || lr:0.002500 || train_loss: 0.251 || train_acc: 0.898
# Epoch: 92/300 || lr:0.002500 || train_loss: 0.237 || train_acc: 0.888
# Epoch: 93/300 || lr:0.002500 || train_loss: 0.237 || train_acc: 0.890
# Epoch: 94/300 || lr:0.002500 || train_loss: 0.217 || train_acc: 0.904
# Epoch: 95/300 || lr:0.002500 || train_loss: 0.280 || train_acc: 0.891
# Epoch: 96/300 || lr:0.002500 || train_loss: 0.266 || train_acc: 0.878
# Epoch: 97/300 || lr:0.002500 || train_loss: 0.244 || train_acc: 0.893
# Epoch: 98/300 || lr:0.002500 || train_loss: 0.249 || train_acc: 0.885
# Epoch: 99/300 || lr:0.002500 || train_loss: 0.223 || train_acc: 0.906
# val_loss: 0.262 || val_acc: 0.897
# Epoch: 100/300 || lr:0.000625 || train_loss: 0.261 || train_acc: 0.887
# Epoch: 101/300 || lr:0.001250 || train_loss: 0.213 || train_acc: 0.901
# Epoch: 102/300 || lr:0.001250 || train_loss: 0.228 || train_acc: 0.899
# Epoch: 103/300 || lr:0.001250 || train_loss: 0.223 || train_acc: 0.905
# Epoch: 104/300 || lr:0.001250 || train_loss: 0.210 || train_acc: 0.919
# Epoch: 105/300 || lr:0.001250 || train_loss: 0.229 || train_acc: 0.897
# Epoch: 106/300 || lr:0.001250 || train_loss: 0.227 || train_acc: 0.897
# Epoch: 107/300 || lr:0.001250 || train_loss: 0.211 || train_acc: 0.903
# Epoch: 108/300 || lr:0.001250 || train_loss: 0.223 || train_acc: 0.909
# Epoch: 109/300 || lr:0.001250 || train_loss: 0.212 || train_acc: 0.907
# val_loss: 0.257 || val_acc: 0.910
# Epoch: 110/300 || lr:0.001250 || train_loss: 0.220 || train_acc: 0.914
# Epoch: 111/300 || lr:0.001250 || train_loss: 0.211 || train_acc: 0.912
# Epoch: 112/300 || lr:0.001250 || train_loss: 0.222 || train_acc: 0.914
# Epoch: 113/300 || lr:0.001250 || train_loss: 0.214 || train_acc: 0.912
# Epoch: 114/300 || lr:0.001250 || train_loss: 0.233 || train_acc: 0.900
# Epoch: 115/300 || lr:0.001250 || train_loss: 0.207 || train_acc: 0.901
# Epoch: 116/300 || lr:0.001250 || train_loss: 0.213 || train_acc: 0.907
# Epoch: 117/300 || lr:0.001250 || train_loss: 0.200 || train_acc: 0.916
# Epoch: 118/300 || lr:0.001250 || train_loss: 0.260 || train_acc: 0.891
# Epoch: 119/300 || lr:0.001250 || train_loss: 0.231 || train_acc: 0.896
# val_loss: 0.241 || val_acc: 0.902
# Epoch: 120/300 || lr:0.001250 || train_loss: 0.202 || train_acc: 0.915
# Epoch: 121/300 || lr:0.001250 || train_loss: 0.201 || train_acc: 0.918
# Epoch: 122/300 || lr:0.001250 || train_loss: 0.204 || train_acc: 0.899
# Epoch: 123/300 || lr:0.001250 || train_loss: 0.224 || train_acc: 0.909
# Epoch: 124/300 || lr:0.001250 || train_loss: 0.223 || train_acc: 0.905
# Epoch: 125/300 || lr:0.001250 || train_loss: 0.194 || train_acc: 0.905
# Epoch: 126/300 || lr:0.001250 || train_loss: 0.239 || train_acc: 0.897
# Epoch: 127/300 || lr:0.001250 || train_loss: 0.233 || train_acc: 0.903
# Epoch: 128/300 || lr:0.001250 || train_loss: 0.204 || train_acc: 0.909
# Epoch: 129/300 || lr:0.001250 || train_loss: 0.209 || train_acc: 0.910
# val_loss: 0.264 || val_acc: 0.910
# Epoch: 130/300 || lr:0.001250 || train_loss: 0.229 || train_acc: 0.898
# Epoch: 131/300 || lr:0.001250 || train_loss: 0.209 || train_acc: 0.906
# Epoch: 132/300 || lr:0.001250 || train_loss: 0.194 || train_acc: 0.912
# Epoch: 133/300 || lr:0.001250 || train_loss: 0.201 || train_acc: 0.913
# Epoch: 134/300 || lr:0.001250 || train_loss: 0.212 || train_acc: 0.910
# Epoch: 135/300 || lr:0.001250 || train_loss: 0.209 || train_acc: 0.901
# Epoch: 136/300 || lr:0.001250 || train_loss: 0.211 || train_acc: 0.907
# Epoch: 137/300 || lr:0.001250 || train_loss: 0.242 || train_acc: 0.900
# Epoch: 138/300 || lr:0.001250 || train_loss: 0.242 || train_acc: 0.889
# Epoch: 139/300 || lr:0.001250 || train_loss: 0.226 || train_acc: 0.895
# val_loss: 0.247 || val_acc: 0.897
# Epoch: 140/300 || lr:0.001250 || train_loss: 0.230 || train_acc: 0.888
# Epoch: 141/300 || lr:0.001250 || train_loss: 0.224 || train_acc: 0.895
# Epoch: 142/300 || lr:0.001250 || train_loss: 0.192 || train_acc: 0.913
# Epoch: 143/300 || lr:0.001250 || train_loss: 0.224 || train_acc: 0.906
# Epoch: 144/300 || lr:0.001250 || train_loss: 0.222 || train_acc: 0.886
# Epoch: 145/300 || lr:0.001250 || train_loss: 0.217 || train_acc: 0.914
# Epoch: 146/300 || lr:0.001250 || train_loss: 0.209 || train_acc: 0.903
# Epoch: 147/300 || lr:0.001250 || train_loss: 0.216 || train_acc: 0.901
# Epoch: 148/300 || lr:0.001250 || train_loss: 0.212 || train_acc: 0.904
# Epoch: 149/300 || lr:0.001250 || train_loss: 0.213 || train_acc: 0.904
# val_loss: 0.270 || val_acc: 0.910
# Epoch: 150/300 || lr:0.000313 || train_loss: 0.180 || train_acc: 0.915
# Epoch: 151/300 || lr:0.000625 || train_loss: 0.251 || train_acc: 0.883
# Epoch: 152/300 || lr:0.000625 || train_loss: 0.203 || train_acc: 0.916
# Epoch: 153/300 || lr:0.000625 || train_loss: 0.197 || train_acc: 0.917
# Epoch: 154/300 || lr:0.000625 || train_loss: 0.179 || train_acc: 0.922
# Epoch: 155/300 || lr:0.000625 || train_loss: 0.198 || train_acc: 0.914
# Epoch: 156/300 || lr:0.000625 || train_loss: 0.200 || train_acc: 0.913
# Epoch: 157/300 || lr:0.000625 || train_loss: 0.193 || train_acc: 0.905
# Epoch: 158/300 || lr:0.000625 || train_loss: 0.221 || train_acc: 0.916
# Epoch: 159/300 || lr:0.000625 || train_loss: 0.175 || train_acc: 0.922
# val_loss: 0.246 || val_acc: 0.897
# Epoch: 160/300 || lr:0.000625 || train_loss: 0.198 || train_acc: 0.920
# Epoch: 161/300 || lr:0.000625 || train_loss: 0.193 || train_acc: 0.922
# Epoch: 162/300 || lr:0.000625 || train_loss: 0.205 || train_acc: 0.911
# Epoch: 163/300 || lr:0.000625 || train_loss: 0.224 || train_acc: 0.905
# Epoch: 164/300 || lr:0.000625 || train_loss: 0.205 || train_acc: 0.904
# Epoch: 165/300 || lr:0.000625 || train_loss: 0.193 || train_acc: 0.918
# Epoch: 166/300 || lr:0.000625 || train_loss: 0.224 || train_acc: 0.896
# Epoch: 167/300 || lr:0.000625 || train_loss: 0.183 || train_acc: 0.916
# Epoch: 168/300 || lr:0.000625 || train_loss: 0.221 || train_acc: 0.912
# Epoch: 169/300 || lr:0.000625 || train_loss: 0.202 || train_acc: 0.895
# val_loss: 0.266 || val_acc: 0.906
# Epoch: 170/300 || lr:0.000625 || train_loss: 0.237 || train_acc: 0.902
# Epoch: 171/300 || lr:0.000625 || train_loss: 0.216 || train_acc: 0.913
# Epoch: 172/300 || lr:0.000625 || train_loss: 0.208 || train_acc: 0.913
# Epoch: 173/300 || lr:0.000625 || train_loss: 0.197 || train_acc: 0.910
# Epoch: 174/300 || lr:0.000625 || train_loss: 0.215 || train_acc: 0.901
# Epoch: 175/300 || lr:0.000625 || train_loss: 0.196 || train_acc: 0.921
# Epoch: 176/300 || lr:0.000625 || train_loss: 0.215 || train_acc: 0.905
# Epoch: 177/300 || lr:0.000625 || train_loss: 0.187 || train_acc: 0.916
# Epoch: 178/300 || lr:0.000625 || train_loss: 0.226 || train_acc: 0.900
# Epoch: 179/300 || lr:0.000625 || train_loss: 0.206 || train_acc: 0.920
# val_loss: 0.274 || val_acc: 0.902
# Epoch: 180/300 || lr:0.000625 || train_loss: 0.187 || train_acc: 0.921
# Epoch: 181/300 || lr:0.000625 || train_loss: 0.200 || train_acc: 0.907
# Epoch: 182/300 || lr:0.000625 || train_loss: 0.195 || train_acc: 0.919
# Epoch: 183/300 || lr:0.000625 || train_loss: 0.187 || train_acc: 0.927
# Epoch: 184/300 || lr:0.000625 || train_loss: 0.184 || train_acc: 0.919
# Epoch: 185/300 || lr:0.000625 || train_loss: 0.191 || train_acc: 0.909
# Epoch: 186/300 || lr:0.000625 || train_loss: 0.206 || train_acc: 0.911
# Epoch: 187/300 || lr:0.000625 || train_loss: 0.205 || train_acc: 0.914
# Epoch: 188/300 || lr:0.000625 || train_loss: 0.214 || train_acc: 0.914
# Epoch: 189/300 || lr:0.000625 || train_loss: 0.217 || train_acc: 0.909
# val_loss: 0.277 || val_acc: 0.897
# Epoch: 190/300 || lr:0.000625 || train_loss: 0.202 || train_acc: 0.913
# Epoch: 191/300 || lr:0.000625 || train_loss: 0.202 || train_acc: 0.920
# Epoch: 192/300 || lr:0.000625 || train_loss: 0.164 || train_acc: 0.926
# Epoch: 193/300 || lr:0.000625 || train_loss: 0.201 || train_acc: 0.905
# Epoch: 194/300 || lr:0.000625 || train_loss: 0.225 || train_acc: 0.911
# Epoch: 195/300 || lr:0.000625 || train_loss: 0.199 || train_acc: 0.910
# Epoch: 196/300 || lr:0.000625 || train_loss: 0.208 || train_acc: 0.898
# Epoch: 197/300 || lr:0.000625 || train_loss: 0.198 || train_acc: 0.906
# Epoch: 198/300 || lr:0.000625 || train_loss: 0.188 || train_acc: 0.905
# Epoch: 199/300 || lr:0.000625 || train_loss: 0.194 || train_acc: 0.913
# val_loss: 0.261 || val_acc: 0.897
# Epoch: 200/300 || lr:0.000156 || train_loss: 0.186 || train_acc: 0.922
# Epoch: 201/300 || lr:0.000313 || train_loss: 0.203 || train_acc: 0.905
# Epoch: 202/300 || lr:0.000313 || train_loss: 0.189 || train_acc: 0.909
# Epoch: 203/300 || lr:0.000313 || train_loss: 0.211 || train_acc: 0.911
# Epoch: 204/300 || lr:0.000313 || train_loss: 0.183 || train_acc: 0.921
# Epoch: 205/300 || lr:0.000313 || train_loss: 0.156 || train_acc: 0.932
# Epoch: 206/300 || lr:0.000313 || train_loss: 0.192 || train_acc: 0.918
# Epoch: 207/300 || lr:0.000313 || train_loss: 0.185 || train_acc: 0.912
# Epoch: 208/300 || lr:0.000313 || train_loss: 0.179 || train_acc: 0.926
# Epoch: 209/300 || lr:0.000313 || train_loss: 0.221 || train_acc: 0.900
# val_loss: 0.261 || val_acc: 0.897
# Epoch: 210/300 || lr:0.000313 || train_loss: 0.197 || train_acc: 0.924
# Epoch: 211/300 || lr:0.000313 || train_loss: 0.208 || train_acc: 0.907
# Epoch: 212/300 || lr:0.000313 || train_loss: 0.212 || train_acc: 0.905
# Epoch: 213/300 || lr:0.000313 || train_loss: 0.176 || train_acc: 0.930
# Epoch: 214/300 || lr:0.000313 || train_loss: 0.186 || train_acc: 0.910
# Epoch: 215/300 || lr:0.000313 || train_loss: 0.189 || train_acc: 0.915
# Epoch: 216/300 || lr:0.000313 || train_loss: 0.193 || train_acc: 0.915
# Epoch: 217/300 || lr:0.000313 || train_loss: 0.195 || train_acc: 0.921
# Epoch: 218/300 || lr:0.000313 || train_loss: 0.195 || train_acc: 0.916
# Epoch: 219/300 || lr:0.000313 || train_loss: 0.183 || train_acc: 0.915
# val_loss: 0.281 || val_acc: 0.893
# Epoch: 220/300 || lr:0.000313 || train_loss: 0.207 || train_acc: 0.912
# Epoch: 221/300 || lr:0.000313 || train_loss: 0.212 || train_acc: 0.909
# Epoch: 222/300 || lr:0.000313 || train_loss: 0.195 || train_acc: 0.913
# Epoch: 223/300 || lr:0.000313 || train_loss: 0.192 || train_acc: 0.916
# Epoch: 224/300 || lr:0.000313 || train_loss: 0.187 || train_acc: 0.926
# Epoch: 225/300 || lr:0.000313 || train_loss: 0.191 || train_acc: 0.924
# Epoch: 226/300 || lr:0.000313 || train_loss: 0.211 || train_acc: 0.920
# Epoch: 227/300 || lr:0.000313 || train_loss: 0.193 || train_acc: 0.914
# Epoch: 228/300 || lr:0.000313 || train_loss: 0.199 || train_acc: 0.913
# Epoch: 229/300 || lr:0.000313 || train_loss: 0.196 || train_acc: 0.917
# val_loss: 0.271 || val_acc: 0.902
# Epoch: 230/300 || lr:0.000313 || train_loss: 0.197 || train_acc: 0.914
# Epoch: 231/300 || lr:0.000313 || train_loss: 0.206 || train_acc: 0.901
# Epoch: 232/300 || lr:0.000313 || train_loss: 0.182 || train_acc: 0.920
# Epoch: 233/300 || lr:0.000313 || train_loss: 0.188 || train_acc: 0.917
# Epoch: 234/300 || lr:0.000313 || train_loss: 0.186 || train_acc: 0.918
# Epoch: 235/300 || lr:0.000313 || train_loss: 0.204 || train_acc: 0.914
# Epoch: 236/300 || lr:0.000313 || train_loss: 0.183 || train_acc: 0.917
# Epoch: 237/300 || lr:0.000313 || train_loss: 0.186 || train_acc: 0.924
# Epoch: 238/300 || lr:0.000313 || train_loss: 0.186 || train_acc: 0.928
# Epoch: 239/300 || lr:0.000313 || train_loss: 0.193 || train_acc: 0.924
# val_loss: 0.279 || val_acc: 0.897
# Epoch: 240/300 || lr:0.000313 || train_loss: 0.200 || train_acc: 0.916
# Epoch: 241/300 || lr:0.000313 || train_loss: 0.179 || train_acc: 0.916
# Epoch: 242/300 || lr:0.000313 || train_loss: 0.183 || train_acc: 0.927
# Epoch: 243/300 || lr:0.000313 || train_loss: 0.183 || train_acc: 0.915
# Epoch: 244/300 || lr:0.000313 || train_loss: 0.205 || train_acc: 0.920
# Epoch: 245/300 || lr:0.000313 || train_loss: 0.171 || train_acc: 0.929
# Epoch: 246/300 || lr:0.000313 || train_loss: 0.188 || train_acc: 0.921
# Epoch: 247/300 || lr:0.000313 || train_loss: 0.197 || train_acc: 0.907
# Epoch: 248/300 || lr:0.000313 || train_loss: 0.183 || train_acc: 0.914
# Epoch: 249/300 || lr:0.000313 || train_loss: 0.205 || train_acc: 0.912
# val_loss: 0.271 || val_acc: 0.897
# Epoch: 250/300 || lr:0.000078 || train_loss: 0.180 || train_acc: 0.922
# Epoch: 251/300 || lr:0.000156 || train_loss: 0.176 || train_acc: 0.934
# Epoch: 252/300 || lr:0.000156 || train_loss: 0.170 || train_acc: 0.922
# Epoch: 253/300 || lr:0.000156 || train_loss: 0.209 || train_acc: 0.921
# Epoch: 254/300 || lr:0.000156 || train_loss: 0.200 || train_acc: 0.914
# Epoch: 255/300 || lr:0.000156 || train_loss: 0.192 || train_acc: 0.928
# Epoch: 256/300 || lr:0.000156 || train_loss: 0.196 || train_acc: 0.920
# Epoch: 257/300 || lr:0.000156 || train_loss: 0.197 || train_acc: 0.907
# Epoch: 258/300 || lr:0.000156 || train_loss: 0.208 || train_acc: 0.911
# Epoch: 259/300 || lr:0.000156 || train_loss: 0.164 || train_acc: 0.922
# val_loss: 0.257 || val_acc: 0.897
# Epoch: 260/300 || lr:0.000156 || train_loss: 0.186 || train_acc: 0.925
# Epoch: 261/300 || lr:0.000156 || train_loss: 0.183 || train_acc: 0.921
# Epoch: 262/300 || lr:0.000156 || train_loss: 0.190 || train_acc: 0.911
# Epoch: 263/300 || lr:0.000156 || train_loss: 0.187 || train_acc: 0.919
# Epoch: 264/300 || lr:0.000156 || train_loss: 0.184 || train_acc: 0.920
# Epoch: 265/300 || lr:0.000156 || train_loss: 0.206 || train_acc: 0.910
# Epoch: 266/300 || lr:0.000156 || train_loss: 0.244 || train_acc: 0.919
# Epoch: 267/300 || lr:0.000156 || train_loss: 0.194 || train_acc: 0.917
# Epoch: 268/300 || lr:0.000156 || train_loss: 0.199 || train_acc: 0.925
# Epoch: 269/300 || lr:0.000156 || train_loss: 0.173 || train_acc: 0.915
# val_loss: 0.276 || val_acc: 0.902
# Epoch: 270/300 || lr:0.000156 || train_loss: 0.194 || train_acc: 0.916
# Epoch: 271/300 || lr:0.000156 || train_loss: 0.208 || train_acc: 0.911
# Epoch: 272/300 || lr:0.000156 || train_loss: 0.197 || train_acc: 0.910
# Epoch: 273/300 || lr:0.000156 || train_loss: 0.194 || train_acc: 0.917
# Epoch: 274/300 || lr:0.000156 || train_loss: 0.177 || train_acc: 0.926
# Epoch: 275/300 || lr:0.000156 || train_loss: 0.207 || train_acc: 0.913
# Epoch: 276/300 || lr:0.000156 || train_loss: 0.191 || train_acc: 0.927
# Epoch: 277/300 || lr:0.000156 || train_loss: 0.197 || train_acc: 0.922
# Epoch: 278/300 || lr:0.000156 || train_loss: 0.179 || train_acc: 0.929
# Epoch: 279/300 || lr:0.000156 || train_loss: 0.170 || train_acc: 0.931
# val_loss: 0.290 || val_acc: 0.902
# Epoch: 280/300 || lr:0.000156 || train_loss: 0.186 || train_acc: 0.926
# Epoch: 281/300 || lr:0.000156 || train_loss: 0.209 || train_acc: 0.913
# Epoch: 282/300 || lr:0.000156 || train_loss: 0.174 || train_acc: 0.934
# Epoch: 283/300 || lr:0.000156 || train_loss: 0.198 || train_acc: 0.916
# Epoch: 284/300 || lr:0.000156 || train_loss: 0.196 || train_acc: 0.913
# Epoch: 285/300 || lr:0.000156 || train_loss: 0.180 || train_acc: 0.914
# Epoch: 286/300 || lr:0.000156 || train_loss: 0.178 || train_acc: 0.928
# Epoch: 287/300 || lr:0.000156 || train_loss: 0.183 || train_acc: 0.914
# Epoch: 288/300 || lr:0.000156 || train_loss: 0.169 || train_acc: 0.938
# Epoch: 289/300 || lr:0.000156 || train_loss: 0.190 || train_acc: 0.920
# val_loss: 0.256 || val_acc: 0.910
# Epoch: 290/300 || lr:0.000156 || train_loss: 0.183 || train_acc: 0.919
# Epoch: 291/300 || lr:0.000156 || train_loss: 0.194 || train_acc: 0.922
# Epoch: 292/300 || lr:0.000156 || train_loss: 0.187 || train_acc: 0.922
# Epoch: 293/300 || lr:0.000156 || train_loss: 0.200 || train_acc: 0.914
# Epoch: 294/300 || lr:0.000156 || train_loss: 0.204 || train_acc: 0.909
# Epoch: 295/300 || lr:0.000156 || train_loss: 0.193 || train_acc: 0.921
# Epoch: 296/300 || lr:0.000156 || train_loss: 0.194 || train_acc: 0.921
# Epoch: 297/300 || lr:0.000156 || train_loss: 0.203 || train_acc: 0.918
# Epoch: 298/300 || lr:0.000156 || train_loss: 0.186 || train_acc: 0.918
# Epoch: 299/300 || lr:0.000156 || train_loss: 0.176 || train_acc: 0.922
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# val_loss: 0.253 || val_acc: 0.902
